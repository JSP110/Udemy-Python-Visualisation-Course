# %%
import numpy as np

# %%
5/2
# Out:
# 2.5

# %%
arr1 = np.array([[1,2,3,4],[8,9,10,11]])

# %%
arr1
# Out:
# array([[ 1,  2,  3,  4],
#        [ 8,  9, 10, 11]])

# %%
arr1*arr1
# Out:
# array([[  1,   4,   9,  16],
#        [ 64,  81, 100, 121]])

# %%
1/arr1
# Out:
# array([[ 1.        ,  0.5       ,  0.33333333,  0.25      ],
#        [ 0.125     ,  0.11111111,  0.1       ,  0.09090909]])

# %%
arr1^3
# Out:
# array([[ 2,  1,  0,  7],
#        [11, 10,  9,  8]])

# %%
arr1**3
# Out:
# array([[   1,    8,   27,   64],
#        [ 512,  729, 1000, 1331]])
