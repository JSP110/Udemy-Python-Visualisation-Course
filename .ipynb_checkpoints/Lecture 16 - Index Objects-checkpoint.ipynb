# %%
import numpy as np

# %%
import pandas as pd

# %%
from pandas import Series,DataFrame

# %%
my_ser = Series ([1,2,3,4],index = ['A','B','C','D'])
my_ser
# Out:
# A    1
# B    2
# C    3
# D    4
# dtype: int64

# %%
my_index = my_ser.index
my_index
# Out:
# Index(['A', 'B', 'C', 'D'], dtype='object')

# %%
my_index[2]
# Out:
# 'C'

# %%
my_index[2:]
# Out:
# Index(['C', 'D'], dtype='object')

# %%
my_index[2] = 'Z'
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-9-88df94607190> in <module>()
# ----> 1 my_index[2] = 'Z'
#
# /Users/jspang/anaconda/lib/python3.4/site-packages/pandas/core/index.py in __setitem__(self, key, value)
#    1055
#    1056     def __setitem__(self, key, value):
# -> 1057         raise TypeError("Indexes does not support mutable operations")
#    1058
#    1059     def __getitem__(self, key):
#
# TypeError: Indexes does not support mutable operations
